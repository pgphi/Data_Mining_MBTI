# %%
import pandas as pd
#Preprocessing Functions wiht all our Steps.#
#Create new Datasets with group_prepro_data
#Create a whole dataset again with standardized 0-15 
#Phillip forgot one type in the label datasets ,find out and add the missing one 
df = pd.read_csv("data\mbti_1.csv")
#df.head()

# %%
#Function Definitions (maybe move into src\preprocessing.py later)
import re
import tldextract
from nltk.corpus import stopwords
import nltk
from nltk.stem import WordNetLemmatizer
import string

#Remove non-alpha characters and preservers whitespaces (me420 i'm done that's it!!! --> me im done thats it)
def remove_non_alpha_words(posts: str) -> str:
    
    #Removes non alphabet chars and \s for matching whitespace
    regex = re.compile('[^a-zA-Z\s]')
    posts = regex.sub('', posts)
    return posts


#Replaces URLs with Second-Level-Domain (https://www.youtube.com/watch?v=dQw4w9WgXcQ --> youtube)
def replace_url_with_domain(posts: str) -> str:
    
    url_list = url_list = re.findall(r'(https?://[^\s]+)', posts)

    if len(url_list) > 0:
        for url in url_list:
            domain = tldextract.extract(url).domain
            posts = posts.replace(url, domain)

    return posts


#Corrects expressive lengthening / word lengthening (hellooo --> hello)
def correct_expressive_lengthening(posts: str) -> str:
    
    return re.sub(r'(.)\1{3,}', r'\1', posts)


def tokenize_posts(posts: str) -> list[str]:
    tokens = nltk.word_tokenize(posts.lower())
    return tokens


def remove_stopwords(tokens):
    stopwords_ = set(stopwords.words("english"))

    #https://escholarship.org/content/qt6n5652cx/qt6n5652cx.pdf
    paper_words = ["got", "a", "i", "il", "be", "the", "of", "do", "not", "can", "am"]

    custom_stopwords = stopwords_ - set(paper_words)

    clean_tokens = []
    for token in tokens:
        if token not in custom_stopwords:
            clean_tokens.append(token)

    return clean_tokens
    
    
def lemmatize_posts(tokens):
    lemmatizer = WordNetLemmatizer()
    lemmas = []
    for w in tokens:
        # print("Lemma for {} is {}".format(w, lemmatizer.lemmatize(w)))
        lemmas.append(lemmatizer.lemmatize(w))
    return lemmas

# %%
test_post = "This myself is a post i am got ||| . a canceled, nevermind dogs dog horse shoe3232 https://www.yotube.com/?h2huihiudas woman nevermind cancer infj entp marauder stefan"

test_post = replace_url_with_domain(test_post)
test_post = remove_non_alpha_words(test_post)
test_post = tokenize_posts(test_post)
test_post = remove_stopwords(test_post)
test_post = lemmatize_posts(test_post)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df["encodedType"] = le.fit_transform(df["type"])
df.head()
# Out:
#    type                                              posts  encodedType
# 0  INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...            8
# 1  ENTP  'I'm finding the lack of me in these posts ver...            3
# 2  INTP  'Good one  _____   https://www.youtube.com/wat...           11
# 3  INTJ  'Dear INTP,   I enjoyed our conversation the o...           10
# 4  ENTJ  'You're fired.|||That's another silly misconce...            2

# %%
df["preprocessed_posts"] = df["posts"]
df.head()
# Out:
#    type                                              posts  encodedType  \
# 0  INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...            8
# 1  ENTP  'I'm finding the lack of me in these posts ver...            3
# 2  INTP  'Good one  _____   https://www.youtube.com/wat...           11
# 3  INTJ  'Dear INTP,   I enjoyed our conversation the o...           10
# 4  ENTJ  'You're fired.|||That's another silly misconce...            2
#
#                                   preprocessed_posts
# 0  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...
# 1  'I'm finding the lack of me in these posts ver...
# 2  'Good one  _____   https://www.youtube.com/wat...
# 3  'Dear INTP,   I enjoyed our conversation the o...
# 4  'You're fired.|||That's another silly misconce...

# %%
df["preprocessed_posts"] = df["preprocessed_posts"].apply(replace_url_with_domain)
df.head()
# Out:
#    type                                              posts  encodedType  \
# 0  INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...            8
# 1  ENTP  'I'm finding the lack of me in these posts ver...            3
# 2  INTP  'Good one  _____   https://www.youtube.com/wat...           11
# 3  INTJ  'Dear INTP,   I enjoyed our conversation the o...           10
# 4  ENTJ  'You're fired.|||That's another silly misconce...            2
#
#                                   preprocessed_posts
# 0  'youtube and intj moments  youtube  sportscent...
# 1  'I'm finding the lack of me in these posts ver...
# 2  'Good one  _____   youtube course, to which I ...
# 3  'Dear INTP,   I enjoyed our conversation the o...
# 4  'You're fired.|||That's another silly misconce...

# %%
df["preprocessed_posts"] = df["preprocessed_posts"].apply(remove_non_alpha_words)
df.head()
# Out:
#    type                                              posts  encodedType  \
# 0  INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...            8
# 1  ENTP  'I'm finding the lack of me in these posts ver...            3
# 2  INTP  'Good one  _____   https://www.youtube.com/wat...           11
# 3  INTJ  'Dear INTP,   I enjoyed our conversation the o...           10
# 4  ENTJ  'You're fired.|||That's another silly misconce...            2
#
#                                   preprocessed_posts
# 0  youtube and intj moments  youtube  sportscente...
# 1  Im finding the lack of me in these posts very ...
# 2  Good one     youtube course to which I say I k...
# 3  Dear INTP   I enjoyed our conversation the oth...
# 4  Youre firedThats another silly misconception T...

# %%
df["preprocessed_posts"] = df["preprocessed_posts"].apply(tokenize_posts)
df.head()
# Out:
#    type                                              posts  encodedType  \
# 0  INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...            8
# 1  ENTP  'I'm finding the lack of me in these posts ver...            3
# 2  INTP  'Good one  _____   https://www.youtube.com/wat...           11
# 3  INTJ  'Dear INTP,   I enjoyed our conversation the o...           10
# 4  ENTJ  'You're fired.|||That's another silly misconce...            2
#
#                                   preprocessed_posts
# 0  [youtube, and, intj, moments, youtube, sportsc...
# 1  [im, finding, the, lack, of, me, in, these, po...
# 2  [good, one, youtube, course, to, which, i, say...
# 3  [dear, intp, i, enjoyed, our, conversation, th...
# 4  [youre, firedthats, another, silly, misconcept...

# %%
df["preprocessed_posts"] = df["preprocessed_posts"].apply(remove_stopwords)
df.head()
# Out:
#    type                                              posts  encodedType  \
# 0  INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...            8
# 1  ENTP  'I'm finding the lack of me in these posts ver...            3
# 2  INTP  'Good one  _____   https://www.youtube.com/wat...           11
# 3  INTJ  'Dear INTP,   I enjoyed our conversation the o...           10
# 4  ENTJ  'You're fired.|||That's another silly misconce...            2
#
#                                   preprocessed_posts
# 0  [youtube, intj, moments, youtube, sportscenter...
# 1  [im, finding, the, lack, of, posts, alarmingse...
# 2  [good, one, youtube, course, i, say, i, know, ...
# 3  [dear, intp, i, enjoyed, conversation, the, da...
# 4  [youre, firedthats, another, silly, misconcept...

# %%
df["preprocessed_posts"] = df["preprocessed_posts"].apply(lemmatize_posts)
df.head()

# %%
#Encode 0-15 with Standard encoding

#create train_test split with test_size = 0.3 and random_state = 42069

#Save train and test datasets.csv
